# %% [markdown]
# ## Курс "Анализ временных рядов"

# %% [markdown]
# ### Задание 4

# %% [markdown]
# ### Знакомство с TSAI

# %% [markdown]
# Одним из наиболее современных пакетов работы с временными рядами при помощи глубокого обучения нейронных сетей является пакет [**`TSAI`**](https://github.com/timeseriesAI/tsai), официальная документация по данному пакету может быть найдена [тут](https://timeseriesai.github.io/tsai/).
#
# Пакет `tsai` — это пакет глубокого обучения с открытым исходным кодом, созданный на основе фреймворков `Pytorch` и `fastai`, ориентированный на современные методы для задач временных рядов, таких как классификация, регрессия, прогнозирование, вменение.
#
# Для установки пакета разработчиками рекомендуется следующий скрипт:
# ```python
# stable = True # Set to True for latest pip version or False for main branch in GitHub
# !pip install {"tsai -U" if stable else "git+https://github.com/timeseriesAI/tsai.git"} >> /dev/null
# ```
# Теперь рассмотрим импорт пакета.

# %%
! pip install tsai
# Out:
# Collecting tsai
#   Downloading tsai-0.3.6-py3-none-any.whl (298 kB)
#      ------------------------------------ 298.9/298.9 kB 499.5 kB/s eta 0:00:00
# Collecting pyts>=0.12.0
#   Using cached pyts-0.12.0-py3-none-any.whl (2.5 MB)
# Requirement already satisfied: psutil>=5.4.8 in c:\users\mikhail\anaconda3\lib\site-packages (from tsai) (5.9.0)
# Collecting fastai>=2.7.12
#   Using cached fastai-2.7.12-py3-none-any.whl (233 kB)
# Collecting imbalanced-learn>=0.8.0
#   Using cached imbalanced_learn-0.10.1-py3-none-any.whl (226 kB)
# Collecting torch<2.1,>=1.7
#   Downloading torch-2.0.1-cp310-cp310-win_amd64.whl (172.3 MB)
#      ------------------------------------- 172.3/172.3 MB 60.4 kB/s eta 0:00:00
# Requirement already satisfied: scipy in c:\users\mikhail\appdata\roaming\python\python310\site-packages (from fastai>=2.7.12->tsai) (1.10.1)
# Requirement already satisfied: pyyaml in c:\users\mikhail\anaconda3\lib\site-packages (from fastai>=2.7.12->tsai) (6.0)
# Requirement already satisfied: pandas in c:\users\mikhail\appdata\roaming\python\python310\site-packages (from fastai>=2.7.12->tsai) (1.5.3)
# Collecting torchvision>=0.8.2
#   Downloading torchvision-0.15.2-cp310-cp310-win_amd64.whl (1.2 MB)
#      ---------------------------------------- 1.2/1.2 MB 119.5 kB/s eta 0:00:00
# Requirement already satisfied: pillow>6.0.0 in c:\users\mikhail\anaconda3\lib\site-packages (from fastai>=2.7.12->tsai) (9.4.0)
# Collecting spacy<4
#   Downloading spacy-3.5.3-cp310-cp310-win_amd64.whl (12.2 MB)
#      -------------------------------------- 12.2/12.2 MB 434.4 kB/s eta 0:00:00
# Collecting fastcore<1.6,>=1.5.29
#   Downloading fastcore-1.5.29-py3-none-any.whl (67 kB)
#      -------------------------------------- 67.6/67.6 kB 521.4 kB/s eta 0:00:00
# Requirement already satisfied: pip in c:\users\mikhail\anaconda3\lib\site-packages (from fastai>=2.7.12->tsai) (22.3.1)
# Collecting fastprogress>=0.2.4
#   Downloading fastprogress-1.0.3-py3-none-any.whl (12 kB)
# Requirement already satisfied: scikit-learn in c:\users\mikhail\appdata\roaming\python\python310\site-packages (from fastai>=2.7.12->tsai) (1.2.2)
# Collecting fastdownload<2,>=0.0.5
#   Downloading fastdownload-0.0.7-py3-none-any.whl (12 kB)
# Requirement already satisfied: packaging in c:\users\mikhail\anaconda3\lib\site-packages (from fastai>=2.7.12->tsai) (23.0)
# Requirement already satisfied: matplotlib in c:\users\mikhail\anaconda3\lib\site-packages (from fastai>=2.7.12->tsai) (3.7.1)
# Requirement already satisfied: requests in c:\users\mikhail\anaconda3\lib\site-packages (from fastai>=2.7.12->tsai) (2.29.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\mikhail\appdata\roaming\python\python310\site-packages (from imbalanced-learn>=0.8.0->tsai) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mikhail\appdata\roaming\python\python310\site-packages (from imbalanced-learn>=0.8.0->tsai) (3.1.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\mikhail\anaconda3\lib\site-packages (from imbalanced-learn>=0.8.0->tsai) (1.23.5)
# Requirement already satisfied: numba>=0.48.0 in c:\users\mikhail\anaconda3\lib\site-packages (from pyts>=0.12.0->tsai) (0.57.0)
# Requirement already satisfied: typing-extensions in c:\users\mikhail\anaconda3\lib\site-packages (from torch<2.1,>=1.7->tsai) (4.5.0)
# Collecting networkx
#   Using cached networkx-3.1-py3-none-any.whl (2.1 MB)
# Requirement already satisfied: jinja2 in c:\users\mikhail\anaconda3\lib\site-packages (from torch<2.1,>=1.7->tsai) (3.1.2)
# Requirement already satisfied: filelock in c:\users\mikhail\anaconda3\lib\site-packages (from torch<2.1,>=1.7->tsai) (3.9.0)
# Collecting sympy
#   Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#      ---------------------------------------- 5.7/5.7 MB 540.3 kB/s eta 0:00:00
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in c:\users\mikhail\anaconda3\lib\site-packages (from numba>=0.48.0->pyts>=0.12.0->tsai) (0.40.0)
# Collecting typer<0.8.0,>=0.3.0
#   Downloading typer-0.7.0-py3-none-any.whl (38 kB)
# Collecting pathy>=0.10.0
#   Downloading pathy-0.10.1-py3-none-any.whl (48 kB)
#      -------------------------------------- 48.9/48.9 kB 839.6 kB/s eta 0:00:00
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.4-py3-none-any.whl (11 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.7-cp310-cp310-win_amd64.whl (29 kB)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      ------------------------------------ 181.6/181.6 kB 148.3 kB/s eta 0:00:00
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\mikhail\anaconda3\lib\site-packages (from spacy<4->fastai>=2.7.12->tsai) (4.65.0)
# Collecting wasabi<1.2.0,>=0.9.1
#   Downloading wasabi-1.1.1-py3-none-any.whl (27 kB)
# Collecting thinc<8.2.0,>=8.1.8
#   Downloading thinc-8.1.10-cp310-cp310-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 653.7 kB/s eta 0:00:00
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.9-cp310-cp310-win_amd64.whl (18 kB)
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.8-py3-none-any.whl (17 kB)
# Requirement already satisfied: setuptools in c:\users\mikhail\anaconda3\lib\site-packages (from spacy<4->fastai>=2.7.12->tsai) (65.6.3)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.8-cp310-cp310-win_amd64.whl (94 kB)
#      ---------------------------------------- 94.7/94.7 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\mikhail\anaconda3\lib\site-packages (from spacy<4->fastai>=2.7.12->tsai) (1.10.7)
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.6-cp310-cp310-win_amd64.whl (480 kB)
#      ------------------------------------ 480.9/480.9 kB 257.5 kB/s eta 0:00:00
# Collecting smart-open<7.0.0,>=5.2.1
#   Downloading smart_open-6.3.0-py3-none-any.whl (56 kB)
#      -------------------------------------- 56.8/56.8 kB 372.1 kB/s eta 0:00:00
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mikhail\anaconda3\lib\site-packages (from requests->fastai>=2.7.12->tsai) (1.26.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mikhail\anaconda3\lib\site-packages (from requests->fastai>=2.7.12->tsai) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mikhail\anaconda3\lib\site-packages (from requests->fastai>=2.7.12->tsai) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mikhail\anaconda3\lib\site-packages (from requests->fastai>=2.7.12->tsai) (3.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mikhail\anaconda3\lib\site-packages (from jinja2->torch<2.1,>=1.7->tsai) (2.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mikhail\anaconda3\lib\site-packages (from matplotlib->fastai>=2.7.12->tsai) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\mikhail\anaconda3\lib\site-packages (from matplotlib->fastai>=2.7.12->tsai) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mikhail\anaconda3\lib\site-packages (from matplotlib->fastai>=2.7.12->tsai) (4.39.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mikhail\anaconda3\lib\site-packages (from matplotlib->fastai>=2.7.12->tsai) (1.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mikhail\anaconda3\lib\site-packages (from matplotlib->fastai>=2.7.12->tsai) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mikhail\anaconda3\lib\site-packages (from matplotlib->fastai>=2.7.12->tsai) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mikhail\anaconda3\lib\site-packages (from pandas->fastai>=2.7.12->tsai) (2022.7)
# Collecting mpmath>=0.19
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ------------------------------------ 536.2/536.2 kB 601.1 kB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\users\mikhail\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->fastai>=2.7.12->tsai) (1.16.0)
# Collecting blis<0.8.0,>=0.7.8
#   Downloading blis-0.7.9-cp310-cp310-win_amd64.whl (7.0 MB)
#      ---------------------------------------- 7.0/7.0 MB 967.4 kB/s eta 0:00:00
# Collecting confection<1.0.0,>=0.0.1
#   Downloading confection-0.0.4-py3-none-any.whl (32 kB)
# Requirement already satisfied: colorama in c:\users\mikhail\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<4->fastai>=2.7.12->tsai) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\mikhail\anaconda3\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy<4->fastai>=2.7.12->tsai) (8.1.3)
# Installing collected packages: mpmath, cymem, wasabi, sympy, spacy-loggers, spacy-legacy, smart-open, networkx, murmurhash, langcodes, fastprogress, fastcore, catalogue, blis, typer, torch, srsly, preshed, fastdownload, torchvision, pyts, pathy, imbalanced-learn, confection, thinc, spacy, fastai, tsai
# Successfully installed blis-0.7.9 catalogue-2.0.8 confection-0.0.4 cymem-2.0.7 fastai-2.7.12 fastcore-1.5.29 fastdownload-0.0.7 fastprogress-1.0.3 imbalanced-learn-0.10.1 langcodes-3.3.0 mpmath-1.3.0 murmurhash-1.0.9 networkx-3.1 pathy-0.10.1 preshed-3.0.8 pyts-0.12.0 smart-open-6.3.0 spacy-3.5.3 spacy-legacy-3.0.12 spacy-loggers-1.0.4 srsly-2.4.6 sympy-1.12 thinc-8.1.10 torch-2.0.1 torchvision-0.15.2 tsai-0.3.6 typer-0.7.0 wasabi-1.1.1

# %%
from tsai.all import *
import warnings

computer_setup()
# Out:
# os              : Windows-10-10.0.22000-SP0
# python          : 3.10.9
# tsai            : 0.3.6
# fastai          : 2.7.12
# fastcore        : 1.5.29
# torch           : 2.0.1+cpu
# cpu cores       : 4
# threads per cpu : 2
# RAM             : 6.94 GB
# GPU memory      : N/A

# %%
from sklearn.model_selection import train_test_split

# %%
import torch
from torch import nn

# %% [markdown]
# Теперь давайте выберем данные. Мы будем использовать тот же пример, что и для классификации в `SKTime` - набором данных [открытые данные энергетических систем](https://open-power-system-data.org/).

# %%
def extract_country(df_all, country_code, year_min=None, year_max=None):
    # List of columns to extract
    columns = [col for col in df_all.columns if col.startswith(country_code)]
    # Extract columns and remove country codes from column labels
    columns_map = {col : col[3:] for col in columns}
    df_out = df_all[columns].rename(columns=columns_map)
    # Exclude years outside of specified range, if any
    if year_min is not None:
        df_out = df_out[df_out.index.year >= year_min]
    if year_max is not None:
        df_out = df_out[df_out.index.year <= year_max]
    return df_out

def transform_dataframe(df, cols_map):
    # Rename columns for convenience
    df = df[list(cols_map.keys())].rename(columns=cols_map)    
    df = df / 1000 # Convert from MW to GW
    df = df.rename_axis('Date')
    return df

def split_by_month(df, months):
    df_ = pd.DataFrame()
    for month in np.atleast_1d(months):
        df_ = df_.append(df.loc[df.index.month == month])
    return df_

def to_segments(df, column, size = 24):  
    df.index.hour[0]
    start_idx = 24-df.index.hour[0]
    df = df.iloc[start_idx:]
    val = df[[column]].values
    return val[:size*(val.size//size)].reshape(-1,size)

# %%
url = 'https://data.open-power-system-data.org/time_series/2020-10-06/'
datafile = url + 'time_series_60min_singleindex.csv'
df_all = pd.read_csv(datafile, index_col='utc_timestamp', parse_dates=True, low_memory=False)

df_hrly = extract_country(df_all, country_code='DK', year_min=2015, year_max=2019)

df_hrly.sample(3)

cols_map = {'load_actual_entsoe_transparency' : 'Consumption',
            'wind_generation_actual' : 'Wind',
            'solar_generation_actual' : 'Solar'}
df = transform_dataframe(df_hrly, cols_map).dropna()

# df wind + solar generation
df['Wind+Solar'] = df[['Wind', 'Solar']].sum(axis=1, skipna=False)
df.to_csv('dk_clf_data.csv')
df.head()
# Out:
#                            Consumption     Wind    Solar  Wind+Solar
# Date
# 2015-01-01 04:00:00+00:00      2.94154  3.09201  0.00001     3.09202
# 2015-01-01 05:00:00+00:00      2.99989  3.27063  0.00001     3.27064
# 2015-01-01 06:00:00+00:00      3.17680  3.50255  0.00001     3.50256
# 2015-01-01 07:00:00+00:00      3.29227  3.70607  0.00003     3.70610
# 2015-01-01 08:00:00+00:00      3.37864  3.84748  0.00150     3.84898

# %%
winter = to_segments(split_by_month(df, [1,2, 12]), 'Consumption', size = 24)
summer = to_segments(split_by_month(df, [6, 7, 8]), 'Consumption', size = 24)
autumn = to_segments(split_by_month(df, [9,10,11]), 'Consumption', size = 24)
spring = to_segments(split_by_month(df, [3, 4, 5]), 'Consumption', size = 24)
print(winter.shape, summer.shape, autumn.shape, spring.shape)

X = np.concatenate((
                    winter, 
                    summer, 
                    autumn, 
                    spring))
y = np.concatenate((
                    1*np.ones(winter.shape[0]),
                    2*np.ones(summer.shape[0]),
                    3*np.ones(autumn.shape[0]),
                    4*np.ones(spring.shape[0])
                   ))


X = np.atleast_3d(X).transpose(0,2,1)
y.astype(int)
# Out:
# (450, 24) (459, 24) (454, 24) (459, 24)
# array([1, 1, 1, ..., 4, 4, 4])

# %% [markdown]
# Также давайте сопоставим названия классов и их номера для большего удобства.

# %%
class_map = {
    1:'winter',   
    2:'summer',   
    3:'autumn',   
    4:'spring',   
    }
class_map

labeler = ReLabeler(class_map)
y = labeler(y)

# %% [markdown]
# Особенностью данного фреймворка (как и его основы `fastai`) является использование супер высокоуровневых API. Это делает фреймворк `tsai` практически декларативным. Для проведения экспериментом нам потребуется лишь выбор модели и набора данных. Все обучение будет происходить в `backend`.
#
# Для работы с наборами данных давайте создадим их разделение на тренировочную, валидационную и тестовую подвыборки. Для этого воспользуемся функцией `get_splits`. В рамках урока мы задаем аргумент `show_plot` чтобы визуализировать разделение данных.

# %%
splits = get_splits(y, 
                    n_splits=1, 
                    valid_size=0.3, 
                    test_size=0.1, 
                    shuffle=True, 
                    balance=False, 
                    stratify=True,
                    random_state=42, 
                    show_plot=True, 
                    verbose=True)
splits
# Out:
# ((#1094) [1634,837,895,1196,613,724,1093,1593,598,1688...],
#  (#546) [1679,1784,1332,1084,253,401,1579,553,1017,856...],
#  (#182) [453,338,675,1547,88,826,171,214,980,1619...])

# %% [markdown]
# Для начала давайте создадим набор данных. Такой набор будет экземпляром класса `TSDatasets`. В наборе данных зададим разделение данных и необходимые преобразования `tfms`.
#
# Также сконфигурируем загрузчик батчей `TSDataLoaders`. Загрузим тренировочный и валидационный наборы данных.

# %%
tfms  = [None, [Categorize()]]
dsets = TSDatasets(X, y, tfms=tfms, splits=splits)
 
bs = 256
dls   = TSDataLoaders.from_dsets(dsets.train, dsets.valid, bs=[bs, bs*2])

# %% [markdown]
# Среди анализируемых архитектур мы рассмотрим рекуррентные `RNN`, `LSTM` и `GRU` ячейки в двух вариантах обычном и плюс. Варианты несколько отличаются по архитектуре. Для обоих вариантов мы рассмотрим архитектуры с 3 и 4 слоями, как двунаправленные, так и нет.
#
# Кроме рекуррентных нейронных сетей мы также попробуем ряд стандартных сверточных архитектур, таких как `ResNet1d`, `xresnet1d`, `InceptionTime `, `XceptionTime` и `TCN`. Данные архитектуры представляют собой стандартные подходы к классификации временных рядов нейронными сетями. Последняя архитектура представляет собой использование идеи расширенной свертки. архитектуры `ResNet1d` и `xresnet1d` отличаются подходом к организации `skipconnection`. Архитектуры `InceptionTime ` и `XceptionTime` представляют собой адаптированные под временные ряды соответствующих сверточных сетей для изображений. Также, для сравнения, мы попробуем использовать смешанную архитектуру `LSTM_FCN`, полносвязную архитектуру FCN и архитектуру трансформер `TST`.
#
# Отметим, что почти все архитектуры в нашем примере мы вызываем "из коробки", подробней с реализациями данных архитектур можно ознакомится в рамках официальной документации.

# %%
archs = [
         (RNNPlus, {'n_layers':3, 'bidirectional': True} ),
         (LSTMPlus,{'n_layers':3, 'bidirectional': True} ),
         (GRUPlus, {'n_layers':3, 'bidirectional': True} ),   
         (RNNPlus, {'n_layers':4, 'bidirectional': True} ),
         (RNNPlus, {'n_layers':4, 'bidirectional': False}),  
         (LSTM,    {'n_layers':3, 'bidirectional': False}), 
         (RNN,     {'n_layers':3, 'bidirectional': True} ), 
         (LSTM,    {'n_layers':3, 'bidirectional': True} ),
         (GRU,     {'n_layers':3, 'bidirectional': True} ),   
         (ResNet, {}), 
         (xresnet1d34, {}), 
         (xresnet1d50_deeper, {}), 
         (InceptionTime, {}), 
         (XceptionTime,  {}), 
         (TCN, {}),   
         (LSTM_FCN, {}), 
         (TST, {}),
         (FCN, {}),   
        ]

# %% [markdown]
# Теперь попробуем запустить обучение.
# Для создания модели используем функцию `create_model`, которая для создает модель в формате совместимом с `PyTorch` для заданной архитектуры и набора гиперпараметров.
#
# В пакете `tsai` обучение проводится для объекта класса `Learner`. Таким образом этот класс описывает модель (обученную архитектуру). Мы приведем лишь самую простую конфигурацию этого класса. Конфигурация включает указание загрузчика данных, модели и метрики. В качестве метрики мы используем точность (`accuracy`). Для запуска обучения в классе `Learner` используется метод `fit_one_cycle`. Для этого метода в качестве параметров мы зададим число эпох обучения и скорость обучения. Остальные параметры оставим по умолчанию. Среди таких параметров будут функция потерь (кросс энтропия) и метод оптимизации `ADAM`.
#
# По результатам обучения каждой модели мы занесем в таблицу полученные результаты, в том числе точность для валидационного набора данных и время обучения.

# %%
from IPython.display import clear_output



results = pd.DataFrame(columns=['arch', 'hyperparams', 'total params', 'train loss', 'valid loss', 'accuracy', 'time'])

for i, (arch, k) in enumerate(archs):
   
    model = create_model(arch, dls=dls, **k)
    
    print(model.__class__.__name__)
    
    learn = Learner(dls, model,  metrics=accuracy)
    start = time.time()
    learn.fit_one_cycle(20, 1e-3)
    elapsed = time.time() - start
    vals = learn.recorder.values[-1]
    results.loc[i] = [arch.__name__, k, count_parameters(model), vals[0], vals[1], vals[2], int(elapsed)]
    results.sort_values(by='accuracy', ascending=False, ignore_index=True, inplace=True)
    clear_output()
    display(results)
# Out:
#        arch                              hyperparams  total params  \
# 0    ResNet                                       {}        478724
# 1   RNNPlus  {'n_layers': 4, 'bidirectional': False}         71304
# 2   RNNPlus   {'n_layers': 4, 'bidirectional': True}        202604
# 3       RNN   {'n_layers': 3, 'bidirectional': True}        142204
# 4   RNNPlus   {'n_layers': 3, 'bidirectional': True}        142204
# 5      LSTM   {'n_layers': 3, 'bidirectional': True}        566404
# 6   GRUPlus   {'n_layers': 3, 'bidirectional': True}        425004
# 7       GRU   {'n_layers': 3, 'bidirectional': True}        425004
# 8  LSTMPlus   {'n_layers': 3, 'bidirectional': True}        566404
# 9      LSTM  {'n_layers': 3, 'bidirectional': False}        203204
#
#    train loss  valid loss  accuracy  time
# 0    0.423153    0.377889  0.857143    36
# 1    0.902479    0.736113  0.694139    13
# 2    0.906124    0.753340  0.679487    32
# 3    0.952572    0.803177  0.655678    23
# 4    1.054757    0.934870  0.598901    24
# 5    1.154975    1.022520  0.521978    44
# 6    1.189893    1.070862  0.520147    74
# 7    1.213354    1.093766  0.507326    73
# 8    1.192883    1.084308  0.492674    45
# 9    1.252346    1.179071  0.439560    18
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 9
#       5 results = pd.DataFrame(columns=['arch', 'hyperparams', 'total params', 'train loss', 'valid loss', 'accuracy', 'time'])
#       7 for i, (arch, k) in enumerate(archs):
# ----> 9     model = create_model(arch, dls=dls, **k)
#      11     print(model.__class__.__name__)
#      13     learn = Learner(dls, model,  metrics=accuracy)
#
# File ~\anaconda3\lib\site-packages\tsai\models\utils.py:175, in build_ts_model(arch, c_in, c_out, seq_len, d, dls, device, verbose, pretrained, weights_path, exclude_head, cut, init, arch_config, **kwargs)
#     173 elif 'xresnet1d' in arch.__name__.lower():
#     174     pv(f'arch: {arch.__name__}(c_in={c_in} c_out={c_out} seq_len={seq_len} arch_config={arch_config} kwargs={kwargs})', verbose)
# --> 175     model = (arch(c_in=c_in, c_out=c_out, seq_len=seq_len, **arch_config, **kwargs)).to(device=device)
#     176 elif 'minirockethead' in arch.__name__.lower():
#     177     pv(f'arch: {arch.__name__}(c_in={c_in} seq_len={seq_len} arch_config={arch_config} kwargs={kwargs})', verbose)
#
# File ~\anaconda3\lib\site-packages\tsai\models\XResNet1d.py:17, in xresnet1d34(c_in, c_out, act, **kwargs)
#      15 def xresnet1d18 (c_in, c_out, act=nn.ReLU, **kwargs): return xresnet18(c_in=c_in, n_out=c_out, act_cls=act, ndim=1, **kwargs)
#      16 @delegates(ResBlock)
# ---> 17 def xresnet1d34 (c_in, c_out, act=nn.ReLU, **kwargs): return xresnet34(c_in=c_in, n_out=c_out, act_cls=act, ndim=1, **kwargs)
#      18 @delegates(ResBlock)
#      19 def xresnet1d50 (c_in, c_out, act=nn.ReLU, **kwargs): return xresnet50(c_in=c_in, n_out=c_out, act_cls=act, ndim=1, **kwargs)
#
# File ~\anaconda3\lib\site-packages\fastai\vision\models\xresnet.py:68, in xresnet34(pretrained, **kwargs)
# ---> 68 def xresnet34 (pretrained=False, **kwargs): return _xresnet(pretrained, 1, [3, 4,  6, 3], **kwargs)
#
# File ~\anaconda3\lib\site-packages\fastai\vision\models\xresnet.py:63, in _xresnet(pretrained, expansion, layers, **kwargs)
#      60 def _xresnet(pretrained, expansion, layers, **kwargs):
#      61     # TODO pretrain all sizes. Currently will fail with non-xrn50
#      62     url = 'https://s3.amazonaws.com/fast-ai-modelzoo/xrn50_940.pth'
# ---> 63     res = XResNet(ResBlock, expansion, layers, **kwargs)
#      64     if pretrained: res.load_state_dict(load_state_dict_from_url(url, map_location='cpu')['model'], strict=False)
#      65     return res
#
# File ~\anaconda3\lib\site-packages\fastai\vision\models\xresnet.py:38, in XResNet.__init__(self, block, expansion, layers, p, c_in, n_out, stem_szs, widen, sa, act_cls, ndim, ks, stride, **kwargs)
#      36 block_szs = [int(o*widen) for o in [64,128,256,512] +[256]*(len(layers)-4)]
#      37 block_szs = [64//expansion] + block_szs
# ---> 38 blocks    = self._make_blocks(layers, block_szs, sa, stride, **kwargs)
#      40 super().__init__(
#      41     *stem, MaxPool(ks=ks, stride=stride, padding=ks//2, ndim=ndim),
#      42     *blocks,
#      43     AdaptiveAvgPool(sz=1, ndim=ndim), Flatten(), nn.Dropout(p),
#      44     nn.Linear(block_szs[-1]*expansion, n_out),
#      45 )
#      46 init_cnn(self)
#
# File ~\anaconda3\lib\site-packages\fastai\vision\models\xresnet.py:49, in XResNet._make_blocks(self, layers, block_szs, sa, stride, **kwargs)
#      48 def _make_blocks(self, layers, block_szs, sa, stride, **kwargs):
# ---> 49     return [self._make_layer(ni=block_szs[i], nf=block_szs[i+1], blocks=l,
#      50                              stride=1 if i==0 else stride, sa=sa and i==len(layers)-4, **kwargs)
#      51             for i,l in enumerate(layers)]
#
# File ~\anaconda3\lib\site-packages\fastai\vision\models\xresnet.py:49, in <listcomp>(.0)
#      48 def _make_blocks(self, layers, block_szs, sa, stride, **kwargs):
# ---> 49     return [self._make_layer(ni=block_szs[i], nf=block_szs[i+1], blocks=l,
#      50                              stride=1 if i==0 else stride, sa=sa and i==len(layers)-4, **kwargs)
#      51             for i,l in enumerate(layers)]
#
# File ~\anaconda3\lib\site-packages\fastai\vision\models\xresnet.py:55, in XResNet._make_layer(self, ni, nf, blocks, stride, sa, **kwargs)
#      53 def _make_layer(self, ni, nf, blocks, stride, sa, **kwargs):
#      54     return nn.Sequential(
# ---> 55         *[self.block(self.expansion, ni if i==0 else nf, nf, stride=stride if i==0 else 1,
#      56                   sa=sa and i==(blocks-1), act_cls=self.act_cls, ndim=self.ndim, ks=self.ks, **kwargs)
#      57           for i in range(blocks)])
#
# File ~\anaconda3\lib\site-packages\fastai\vision\models\xresnet.py:55, in <listcomp>(.0)
#      53 def _make_layer(self, ni, nf, blocks, stride, sa, **kwargs):
#      54     return nn.Sequential(
# ---> 55         *[self.block(self.expansion, ni if i==0 else nf, nf, stride=stride if i==0 else 1,
#      56                   sa=sa and i==(blocks-1), act_cls=self.act_cls, ndim=self.ndim, ks=self.ks, **kwargs)
#      57           for i in range(blocks)])
#
# File ~\anaconda3\lib\site-packages\fastcore\meta.py:40, in PrePostInitMeta.__call__(cls, *args, **kwargs)
#      38 if type(res)==cls:
#      39     if hasattr(res,'__pre_init__'): res.__pre_init__(*args,**kwargs)
# ---> 40     res.__init__(*args,**kwargs)
#      41     if hasattr(res,'__post_init__'): res.__post_init__(*args,**kwargs)
#      42 return res
#
# File ~\anaconda3\lib\site-packages\fastai\layers.py:475, in ResBlock.__init__(self, expansion, ni, nf, stride, groups, reduction, nh1, nh2, dw, g2, sa, sym, norm_type, act_cls, ndim, ks, pool, pool_first, **kwargs)
#     473 k0 = dict(norm_type=norm_type, act_cls=act_cls, ndim=ndim, **kwargs)
#     474 k1 = dict(norm_type=norm2, act_cls=None, ndim=ndim, **kwargs)
# --> 475 convpath  = [ConvLayer(ni,  nh2, ks, stride=stride, groups=ni if dw else groups, **k0),
#     476              ConvLayer(nh2,  nf, ks, groups=g2, **k1)
#     477 ] if expansion == 1 else [
#     478              ConvLayer(ni,  nh1, 1, **k0),
#     479              ConvLayer(nh1, nh2, ks, stride=stride, groups=nh1 if dw else groups, **k0),
#     480              ConvLayer(nh2,  nf, 1, groups=g2, **k1)]
#     481 if reduction: convpath.append(SEModule(nf, reduction=reduction, act_cls=act_cls))
#     482 if sa: convpath.append(SimpleSelfAttention(nf,ks=1,sym=sym))
#
# File ~\anaconda3\lib\site-packages\fastai\layers.py:248, in ConvLayer.__init__(self, ni, nf, ks, stride, padding, bias, ndim, norm_type, bn_1st, act_cls, transpose, init, xtra, bias_std, **kwargs)
#     246 if bias is None: bias = not (bn or inn)
#     247 conv_func = _conv_func(ndim, transpose=transpose)
# --> 248 conv = conv_func(ni, nf, kernel_size=ks, bias=bias, stride=stride, padding=padding, **kwargs)
#     249 act = None if act_cls is None else act_cls()
#     250 init_linear(conv, act, init=init, bias_std=bias_std)
#
# TypeError: Conv1d.__init__() got an unexpected keyword argument 'seq_len'

# %% [markdown]
# Среди полученных результатов хотелось бы выделить `RNNPlus`. Эта архитектура дала результат, оптимальный по соотношению точности и времени работы. Давайте рассмотрим эту архитектуру подробней

# %%
arch = RNNPlus
k = {'n_layers': 4, 'bidirectional': True}
model = create_model(arch, dls=dls, **k)

# %%
model = build_ts_model(RNNPlus, arch_config=k, dls=dls)

# %% [markdown]
# Фреймворк `tsai` предлагает метод определения оптимальной скорости обучения на основе тестов нескольких эпох обучения. Попробуем определить лучшую скорость обучения.

# %%
learn = ts_learner(dls, arch=model, metrics=accuracy) 
learn.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(valley=0.00019054606673307717)

# %% [markdown]
# Теперь снова запустим обучение. В этот раз мы запустим процедуру тренировки с коллбеком, позволяющим отслеживать значения функций потерь в режиме он-лайн.

# %%
learn = Learner(dls, model,  metrics=accuracy)
start = time.time()
learn.fit_one_cycle(n_epoch = 100, lr_max = 0.00009, cbs=ShowGraph())
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.402496</td>
#       <td>1.400387</td>
#       <td>0.216117</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.402374</td>
#       <td>1.397963</td>
#       <td>0.223443</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.400132</td>
#       <td>1.395092</td>
#       <td>0.203297</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.398489</td>
#       <td>1.391650</td>
#       <td>0.201465</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.396442</td>
#       <td>1.387663</td>
#       <td>0.183150</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.394527</td>
#       <td>1.383429</td>
#       <td>0.183150</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.392298</td>
#       <td>1.379266</td>
#       <td>0.320513</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.390025</td>
#       <td>1.374940</td>
#       <td>0.274725</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.387584</td>
#       <td>1.369699</td>
#       <td>0.274725</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.384904</td>
#       <td>1.362828</td>
#       <td>0.267399</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.381781</td>
#       <td>1.353752</td>
#       <td>0.413919</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.378024</td>
#       <td>1.342675</td>
#       <td>0.490842</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.373540</td>
#       <td>1.329289</td>
#       <td>0.474359</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.368023</td>
#       <td>1.309942</td>
#       <td>0.512821</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.361106</td>
#       <td>1.283618</td>
#       <td>0.520147</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.352379</td>
#       <td>1.253271</td>
#       <td>0.509158</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.341536</td>
#       <td>1.224099</td>
#       <td>0.501832</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.329327</td>
#       <td>1.187470</td>
#       <td>0.505495</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.315173</td>
#       <td>1.157920</td>
#       <td>0.514652</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.300181</td>
#       <td>1.128964</td>
#       <td>0.512821</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.284361</td>
#       <td>1.104253</td>
#       <td>0.514652</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.268516</td>
#       <td>1.081155</td>
#       <td>0.527473</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.252036</td>
#       <td>1.061492</td>
#       <td>0.527473</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.235526</td>
#       <td>1.045550</td>
#       <td>0.542125</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.218790</td>
#       <td>1.024549</td>
#       <td>0.536630</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.201989</td>
#       <td>1.003172</td>
#       <td>0.545788</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.184850</td>
#       <td>0.994792</td>
#       <td>0.553114</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1.168647</td>
#       <td>0.978120</td>
#       <td>0.556777</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>1.152718</td>
#       <td>0.971378</td>
#       <td>0.567766</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>1.138224</td>
#       <td>0.979080</td>
#       <td>0.575092</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.124863</td>
#       <td>0.961281</td>
#       <td>0.564103</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>1.111382</td>
#       <td>0.936697</td>
#       <td>0.578755</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>1.096853</td>
#       <td>0.925840</td>
#       <td>0.593407</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>1.082951</td>
#       <td>0.919389</td>
#       <td>0.598901</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>1.069474</td>
#       <td>0.906677</td>
#       <td>0.609890</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>1.056016</td>
#       <td>0.913166</td>
#       <td>0.613553</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>1.043862</td>
#       <td>0.888056</td>
#       <td>0.622711</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>1.031026</td>
#       <td>0.874375</td>
#       <td>0.635531</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>1.017804</td>
#       <td>0.865194</td>
#       <td>0.639194</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>1.005336</td>
#       <td>0.852869</td>
#       <td>0.644689</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.993781</td>
#       <td>0.845970</td>
#       <td>0.642857</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.982324</td>
#       <td>0.835043</td>
#       <td>0.644689</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.970431</td>
#       <td>0.833340</td>
#       <td>0.646520</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.957750</td>
#       <td>0.824303</td>
#       <td>0.650183</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.946061</td>
#       <td>0.817508</td>
#       <td>0.648352</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.935253</td>
#       <td>0.800223</td>
#       <td>0.661172</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.924815</td>
#       <td>0.789407</td>
#       <td>0.666667</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.914577</td>
#       <td>0.779944</td>
#       <td>0.666667</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.903050</td>
#       <td>0.770716</td>
#       <td>0.673993</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.892608</td>
#       <td>0.772219</td>
#       <td>0.683150</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.882644</td>
#       <td>0.759143</td>
#       <td>0.675824</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.873221</td>
#       <td>0.745400</td>
#       <td>0.699634</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.863715</td>
#       <td>0.751175</td>
#       <td>0.679487</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.853883</td>
#       <td>0.738942</td>
#       <td>0.703297</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.844885</td>
#       <td>0.738050</td>
#       <td>0.681319</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.835631</td>
#       <td>0.724901</td>
#       <td>0.694139</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.826296</td>
#       <td>0.712370</td>
#       <td>0.714286</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.817863</td>
#       <td>0.710601</td>
#       <td>0.699634</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.809862</td>
#       <td>0.705781</td>
#       <td>0.706960</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.801608</td>
#       <td>0.700561</td>
#       <td>0.705128</td>
#       <td>0

# %%
learn.plot_metrics()

# %% [markdown]
# Рассмотрим несколько примеров результатов для валидационного набора данных.

# %%
learn.show_results(sharey=True)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# Также давайте попробуем визуализировать результаты. Следующий график показывает вероятность при которой определяется класс для каждого семпла валидационной выборки.

# %%
learn.show_probas()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# Также для анализа ошибок давайте посмотрим на матрицу ошибок.

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# Выберем из матрицы наиболее ошибочные случаи.

# %%
interp.most_confused(min_val=3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# [('autumn', 'winter', 42),
#  ('spring', 'summer', 27),
#  ('winter', 'spring', 12),
#  ('spring', 'autumn', 11),
#  ('autumn', 'spring', 9),
#  ('spring', 'winter', 9),
#  ('winter', 'autumn', 9),
#  ('autumn', 'summer', 7),
#  ('summer', 'autumn', 7),
#  ('summer', 'spring', 7)]

# %% [markdown]
# Помимо прочего попробуем сделать предсказания для тестового набора данных.

# %%
probas, _, preds = learn.get_X_preds(X[splits[2][:5]])
preds, y[splits[2][:5]]
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ("['summer', 'winter', 'summer', 'spring', 'winter']",
#  array(['summer', 'winter', 'summer', 'spring', 'winter'], dtype='<U6'))

# %% [markdown]
# Оценим точность на тестовом наборе данных

# %%
probas, _, preds = learn.get_X_preds(X[splits[2]])
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
class_map = {
    'winter':3,   
    'summer':2,   
    'autumn':0,   
    'spring':1,  
    }
class_map

labeler = ReLabeler(class_map)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(np.argmax(probas,axis=-1), labeler(y[splits[2]]))
# Out:
# 0.7637362637362637

# %% [markdown]
# также покажем возможность сохранить и загрузить наборы данных при помощи `tsai`.

# %%
learn.save_all(path='export', dls_fname='dls', model_fname='model', learner_fname='learner')

# %%
learn = load_learner_all(path='export', dls_fname='dls', model_fname='model', learner_fname='learner')
dls = learn.dls

# %% [markdown]
# Отдельно выгрузить и загрузить модель для работы (не для тренировки) можно при помощи следующего скрипта.

# %%
PATH = Path('./models/RNNn.pkl')
PATH.parent.mkdir(parents=True, exist_ok=True)
learn.export(PATH)

# %%
learn = load_learner(PATH)

# %%
probas, _, preds = learn.get_X_preds(X[splits[2][:5]])
preds, y[splits[2][:5]]
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ("['summer', 'winter', 'summer', 'spring', 'winter']",
#  array(['summer', 'winter', 'summer', 'spring', 'winter'], dtype='<U6'))
